# %% [markdown]
# # 📊 LinkedIn Data Science Jobs Tracker - Exploratory Data Analysis
# *por Renan*
#
# **Objetivo**: Usar o arquivo .csv com as vagas carregadas para avaliar o perfil, palavras-chave e características.
# **Tecnologias**: Jupyter Notebook, Pandas, Matplotlib, Seaborn.

# %%
#Bibliotecas utilizadas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS

# %% [markdown]
# ## 🔍 Etapa 1: Carregar o arquivo .csv  1)`

# %%
arquivo = pd.read_csv('linkedin_datascience_jobs.csv')
arquivo
# Out:
#                                                 title  \
# 0   Consultor Performance Negócios (Cientista / Da...
# 1                           Cientista de Dados Senior
# 2                Data Scientist | Marketing Analytics
# 3   Banco de Talentos - Profissionais com Deficiência
# 4                            Gestor de Tráfego Sênior
# 5   Cientista de Dados Jr. - TI - Data & Analytics...
# 6                               Cientista de Dados JR
# 7                         Cientista de Dados - Júnior
# 8                               Cientista de Dados JR
# 9   Pessoa Cientista de Dados - Vaga afirmativa pa...
# 10  Estágio em Cientista de Dados - Vaga afirmativ...
# 11        Cientista de Dados Senior I Banco Carrefour
# 12                          Cientista de Dados Sênior
# 13  Pessoa Consultora Cientista de Dados I Banco C...
# 14                           Cientista de Dados Pleno
# 15                                 Cientista de Dados
# 16                              Cientista de Dados SR
# 17  Cientista de Dados Pleno (Desenvolvimento de P...
# 18                    Cientista de Dados Especialista
# 19                           Cientista de Dados Pleno
# 20                                 Cientista de dados
# 21                          Cientista de Dados Sênior
# 22                                 Cientista de Dados
# 23                    Cientista de Dados Sênior | CRM
# 24                   Pessoa Cientista de Dados Sênior
# 25                                 Cientista de dados
# 26                          Cientista de Dados Sênior
# 27                     Cientista de Dados Pl - Brasil
# 28   Pessoa Coordenadora Cientista de Dados | Crédito
# 29                          Cientista de Dados Sênior
# 30  ESPECIALISTA EM INOVAÇÃO DIGITAL (CIENTISTA DE...
# 31                           Cientista de Dados Pleno
# 32                                 Cientista de dados
# 33  Cientista de Dados e Analytics Sênior (Crédito...
# 34                              Cientista de dados sr
# 35            Trainee Data Science | Data Masters DP6
# 36  BRA Espec Riscos Credito I - (Afirmativa Pesso...
# 37               Trainee data science data masters dp
# 38                            Business Inteligence PL
# 39  Engenheiro de Dados - Trabalho Remoto | REF#25...
#
#                     company            location        posted  \
# 0                SulAmérica       São Paulo, SP     Há 4 dias
# 1               CSU Digital         Barueri, SP      Há 1 mês
# 2                       DP6       São Paulo, SP     Há 6 dias
# 3                 Cognizant  São Paulo e Região     Há 5 dias
# 4                V4 Company       São Paulo, SP     Há 4 dias
# 5           Alares Internet       São Paulo, SP      Há 1 mês
# 6   Mitsui Sumitomo Seguros       São Paulo, SP  Há 3 semanas
# 7                       IBM       São Paulo, SP  Há 2 semanas
# 8   Mitsui Sumitomo Seguros  São Paulo e Região  Há 3 semanas
# 9                  Artefact       São Paulo, SP    Há 6 horas
# 10                 Artefact       São Paulo, SP     Há 4 dias
# 11   Grupo Carrefour Brasil       São Paulo, SP  Há 3 semanas
# 12                 Bradesco          Osasco, SP     Há 4 dias
# 13   Grupo Carrefour Brasil       São Paulo, SP  Há 3 semanas
# 14                       EY       São Paulo, SP   Há 17 horas
# 15     UltraCon Consultoria       São Paulo, SP     Há 4 dias
# 16         Banco Sofisa S/A       São Paulo, SP      Há 1 mês
# 17               TransUnion       São Paulo, SP     Há 4 dias
# 18                    Porto       São Paulo, SP     Há 3 dias
# 19                    Porto       São Paulo, SP   Há 1 semana
# 20    BRQ Digital Solutions       São Paulo, SP  Há 4 semanas
# 21                    Porto       São Paulo, SP  Há 2 semanas
# 22                  ti inc.  São Paulo e Região      Há 1 mês
# 23                  C6 Bank       São Paulo, SP     Há 5 dias
# 24                 ClickBus       São Paulo, SP      Há 1 mês
# 25     Empresa Confidencial       São Paulo, SP  Há 2 semanas
# 26              Eletromidia       São Paulo, SP     Há 4 dias
# 27                     3778       São Paulo, SP  Há 3 semanas
# 28                  C6 Bank       São Paulo, SP     Há 5 dias
# 29                  Braskem  São Paulo e Região  Há 2 semanas
# 30                  Arcadis  São Paulo e Região  Há 4 semanas
# 31               beAnalytic       São Paulo, SP   Há 1 semana
# 32                 Netvagas       São Paulo, SP     Há 5 dias
# 33         Accenture Brasil       São Paulo, SP      Há 1 mês
# 34                 Netvagas       São Paulo, SP     Há 4 dias
# 35                      DP6       São Paulo, SP     Há 5 dias
# 36         Santander Brasil       São Paulo, SP     Há 2 dias
# 37                 Netvagas       São Paulo, SP     Há 4 dias
# 38                 Bradesco          Osasco, SP    Há 6 horas
# 39                BairesDev     Santo André, SP    Há 3 meses
#
#                                           description  applicants  \
# 0   DescriçãoResponsável por centralizar todos os ...         NaN
# 1   O profissional irá trabalhar com um time multi...         NaN
# 2   Nós somos a DP6!Otimizamos a eficiência do Mar...         NaN
# 3   A Cognizant está sempre à procura de grandes t...         NaN
# 4   🚀 Faça parte da maior unidade da Rede V4 Compa...         NaN
# 5   Você é curioso(a), apaixonado(a) por dados e q...         NaN
# 6   DESCRIÇÃOPrincipais AtividadesApoiar na extraç...         NaN
# 7   IntroductionIn this role you will join IBM Con...         NaN
# 8   Principais AtividadesApoiar na extração, trata...         NaN
# 9   A abertura atual é para a Artefact do Brasil, ...         NaN
# 10  A abertura atual é para a Artefact do Brasil, ...         NaN
# 11  DESCRIÇÃOO Banco Carrefour é a maior Fintail d...         NaN
# 12  Sobre o BradescoO Bradesco é um dos maiores gr...         NaN
# 13  DESCRIÇÃOO Banco Carrefour é a maior Fintail d...         NaN
# 14  A EY é líder global em serviços de Auditoria, ...         NaN
# 15  Cientista de Dados Sr.Data de Início: Imediata...         NaN
# 16  Job DescriptionOrgulhosamente, somos um dos pr...         NaN
# 17  TransUnion's Job Applicant Privacy NoticeWhat ...         NaN
# 18  Job DescriptionO que faz a área Ciência de Dad...         NaN
# 19  Job DescriptionO time de Analytics e Insights ...         NaN
# 20  Profissional Cientista de Dados - PlenoCódigo ...         NaN
# 21  Job DescriptionSuperintendência responsável pe...         NaN
# 22  Elaboração de relatório analítico de dadosSupe...         NaN
# 23  Nossa área de Ciência de DadosA nossa equipe é...         NaN
# 24  O que nos move diariamente?Viabilizamos moment...         NaN
# 25  Principais responsabilidadesIngestão e tratame...         NaN
# 26  Job DescriptionCONECTAMOS HISTÓRIAS, PESSOAS E...         NaN
# 27  A 3778 nasceu com o objetivo de redefinir a ex...         NaN
# 28  Nossa área de Ciência de DadosNosso ambiente d...         NaN
# 29  Job DescriptionEstamos buscando um(a) Cientist...         NaN
# 30  Sobre a Arcadis:A Arcadis é a empresa líder mu...         NaN
# 31  É apaixonado por dados e manda bem em Data Sci...         NaN
# 32  Sobre a empresaSomos focados no desenvolviment...         NaN
# 33  Um time que faz parte da mudançaAbraçamos o po...         NaN
# 34  Impactar positivamente bilhões de vidas é noss...         NaN
# 35  Conquiste o futuro com o Programa Data Masters...         NaN
# 36  Country: BrazilEspec Riscos Credito ISe você t...         NaN
# 37  Conquiste o futuro com o Programa Data Masters...         NaN
# 38  Sobre o BradescoO Bradesco é um dos maiores gr...         NaN
# 39  Há mais de 15 anos, a BairesDev® é líder em pr...         NaN
#
#          work_mode                                               link
# 0   On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 1   On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 2   On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 3   On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 4   On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 5   On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 6   On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 7   On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 8   On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 9   On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 10  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 11  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 12  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 13  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 14  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 15  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 16  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 17  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 18  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 19  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 20  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 21  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 22  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 23  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 24  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 25  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 26  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 27  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 28  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 29  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 30  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 31  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 32  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 33  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 34  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 35  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 36  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 37  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 38  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 39  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...

# %%
# Cria DataFrame
df = pd.DataFrame(arquivo)

# %%
display(df.head())
# Out:
#                                                title      company  \
# 0  Consultor Performance Negócios (Cientista / Da...   SulAmérica
# 1                          Cientista de Dados Senior  CSU Digital
# 2               Data Scientist | Marketing Analytics          DP6
# 3  Banco de Talentos - Profissionais com Deficiência    Cognizant
# 4                           Gestor de Tráfego Sênior   V4 Company
#
#              location     posted  \
# 0       São Paulo, SP  Há 4 dias
# 1         Barueri, SP   Há 1 mês
# 2       São Paulo, SP  Há 6 dias
# 3  São Paulo e Região  Há 5 dias
# 4       São Paulo, SP  Há 4 dias
#
#                                          description  applicants  \
# 0  DescriçãoResponsável por centralizar todos os ...         NaN
# 1  O profissional irá trabalhar com um time multi...         NaN
# 2  Nós somos a DP6!Otimizamos a eficiência do Mar...         NaN
# 3  A Cognizant está sempre à procura de grandes t...         NaN
# 4  🚀 Faça parte da maior unidade da Rede V4 Compa...         NaN
#
#         work_mode                                               link
# 0  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 1  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 2  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 3  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 4  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...

# %%
habilidades = ["sql", "python", "machine learning", "aws", "cloud"]

# %%
df["skills"] = df["description"].apply(lambda desc: [skill for skill in habilidades if re.search(rf"\b{skill}\b", desc.lower())])

# %%
skills_count = pd.Series([skill for sublist in df["skills"] for skill in sublist]).value_counts()
print(skills_count)
# Out:
# python              30
# sql                 28
# machine learning    17
# cloud                8
# aws                  6
# Name: count, dtype: int64

# %%
skills_count.plot(kind="barh", color="darkblue")
plt.title("Top 10 Habilidades em Vagas de Data Science")
plt.show()

# %%
df.head()
# Out:
#                                                title      company  \
# 0  Consultor Performance Negócios (Cientista / Da...   SulAmérica
# 1                          Cientista de Dados Senior  CSU Digital
# 2               Data Scientist | Marketing Analytics          DP6
# 3  Banco de Talentos - Profissionais com Deficiência    Cognizant
# 4                           Gestor de Tráfego Sênior   V4 Company
#
#              location     posted  \
# 0       São Paulo, SP  Há 4 dias
# 1         Barueri, SP   Há 1 mês
# 2       São Paulo, SP  Há 6 dias
# 3  São Paulo e Região  Há 5 dias
# 4       São Paulo, SP  Há 4 dias
#
#                                          description  applicants  \
# 0  DescriçãoResponsável por centralizar todos os ...         NaN
# 1  O profissional irá trabalhar com um time multi...         NaN
# 2  Nós somos a DP6!Otimizamos a eficiência do Mar...         NaN
# 3  A Cognizant está sempre à procura de grandes t...         NaN
# 4  🚀 Faça parte da maior unidade da Rede V4 Compa...         NaN
#
#         work_mode                                               link  \
# 0  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 1  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 2  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 3  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
# 4  On-site/Hybrid  https://www.linkedin.com/jobs-guest/jobs/api/j...
#
#                             skills
# 0                            [sql]
# 1  [sql, python, machine learning]
# 2  [sql, python, machine learning]
# 3                               []
# 4                               []

# %%
descricao_habilidades = df["description"]

# %%
palavras = " ".join(palavra for palavra in descricao_habilidades)

# %%
stopwords = set(STOPWORDS)

# %%
stopwords.update(['vaga', 'nós', 'estar', 'será', 'todos', 'das', 'sempre', 'will', 'etc', 'fazer', 'aos', 'ano', 'os', 'até', 'suas', 'ser', 'além', 'pessoa', 'cada', 'à', 'todas', 'são', 'não', 'nos', 'sua', 'nossos', 'sobre', 'utilizando', 'nossa', 'onde', 'dia', 'todo', 'a', 'de', 'e', 'para', 'em', 'da', 'atividades', 'principais', 'do', 'somos', 'um', 'é', 'está', 'busca', 'buscando', 'dados', 'que', 'o', 'nosso', 'na', 'como', 'você', 'trabalhar', 'ou', 'mais','ao','seu','por','toda','less', 'more', 'Show', 'se', 'uma', 'dos', 'estamos', 'moreShow', 'você', 'deficiência', 'disability', 'odontológico', 'saúde', 'nossas', 'Entrevista', 'anos','parte','pelo', 'Desconto', 'aqui'])

# %%
wordcloud = WordCloud(stopwords=stopwords,
    width=800, 
    height=400,
    background_color='white',  # fundo branco
    colormap='viridis',       # esquema de cores
    contour_width=1,          # borda ao redor da nuvem
    contour_color='steelblue',# cor da borda
    max_words=150,            # limitar número de palavras
    collocations=False,       # evitar repetições de frases
    prefer_horizontal=0.8,    # proporção de palavras horizontais
    min_font_size=4,          # tamanho mínimo da fonte
    random_state=42           # para reprodutibilidade
).generate(palavras)

# Configurar figura
plt.figure(figsize=(12, 8), facecolor='white', edgecolor='blue')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# Título
plt.title("Habilidades descritas nas vagas do Linkedin - Mapa de Palavras", 
          fontsize=16, pad=20, color='#333333')
plt.tight_layout(pad=1)  # ajustar espaçamento

# Opcional: salvar
#plt.savefig('wordcloud_profissional.png', dpi=300, bbox_inches='tight', quality=100)

plt.show()

# %%
# Configurações visuais
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# %%
if df["work_mode"].nunique() > 1:
    sns.countplot(x="work_mode", data=df)
    plt.title("Distribuição por Modalidade de Trabalho")
    plt.show()
else:
    print("Todas as vagas são:", df['work_mode'].iloc[0])
# Out:
# Todas as vagas são: On-site/Hybrid

# %%
# Dados
company_counts = df["company"].value_counts().head(10)

# Estilo visual
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

# Gráfico de barras horizontais
ax = sns.barplot(x=company_counts.values, y=company_counts.index, palette="Blues_d")

# Título e rótulos
plt.title("Top 10 Empresas com Mais Vagas de Data Science", fontsize=14, pad=15)
plt.xlabel("Número de Vagas")
plt.ylabel("Empresa")

# Adiciona os valores dentro das barras
for i, (v, label) in enumerate(zip(company_counts.values, company_counts.index)):
    ax.text(v - 0.5, i, str(v), color='white', va='center', ha='right', fontweight='bold')

# Ajusta layout
plt.tight_layout()
plt.show()
